# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# Collecting pygit2==1.15.1
#   Downloading pygit2-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: cffi>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pygit2==1.15.1) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.16.0->pygit2==1.15.1) (2.22)
# Downloading pygit2-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 38.2 MB/s eta 0:00:00
# Installing collected packages: pygit2
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.17.0
#     Uninstalling pygit2-1.17.0:
#       Successfully uninstalled pygit2-1.17.0
# Successfully installed pygit2-1.15.1
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6725, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6725 (delta 2), reused 0 (delta 0), pack-reused 6721 (from 3)
# Receiving objects: 100% (6725/6725), 33.27 MiB | 22.65 MiB/s, done.
# Resolving deltas: 100% (3875/3875), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 9.62MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 8.25MB/s]
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/xl-to-v1_interposer-v4.0.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v4.0.safetensors
#
# 100% 5.40M/5.40M [00:00<00:00, 40.8MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_expansion.bin" to /content/Fooocus/models/prompt_expansion/fooocus_expansion/pytorch_model.bin
#
# 100% 335M/335M [00:01<00:00, 237MB/s]
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/juggernautXL_v8Rundiffusion.safetensors" to /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
#
# 100% 6.62G/6.62G [00:34<00:00, 206MB/s]
# Downloading: "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors" to /content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors
#
# 100% 47.3M/47.3M [00:00<00:00, 192MB/s]
# Total VRAM 15095 MB, total RAM 12979 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7865
# Running on public URL: https://0e65ece9a648ab8a49.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_l.logit_scale'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
# VAE loaded: None
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.59 seconds
# 2025-02-19 12:09:37.892341: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739966978.126194    1864 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739966978.195606    1864 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-19 12:09:38.690411: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Started worker with PID 895
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://0e65ece9a648ab8a49.gradio.live
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/gradio/blocks.py", line 2199, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/Fooocus/entry_with_update.py", line 46, in <module>
#     from launch import *
#   File "/content/Fooocus/launch.py", line 152, in <module>
#     from webui import *
#   File "/content/Fooocus/webui.py", line 1120, in <module>
#     shared.gradio_root.launch(
#   File "/usr/local/lib/python3.11/dist-packages/gradio/blocks.py", line 2115, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.11/dist-packages/gradio/blocks.py", line 2203, in block_thread
#     self.server.close()
#   File "/usr/local/lib/python3.11/dist-packages/gradio/networking.py", line 49, in close
#     self.thread.join()
#   File "/usr/lib/python3.11/threading.py", line 1119, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.11/threading.py", line 1139, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Killing tunnel 127.0.0.1:7865 <> https://0e65ece9a648ab8a49.gradio.live

# %%
# !python entry_with_update.py --share --always-high-vram
# Out:
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Total VRAM 15095 MB, total RAM 12979 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7865
# Running on public URL: https://340bf10089e68ef131.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_l.logit_scale'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
# VAE loaded: None
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.63 seconds
# 2025-02-19 13:35:17.007160: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739972117.031582   23134 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739972117.039540   23134 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-19 13:35:17.086309: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Started worker with PID 23070
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://340bf10089e68ef131.gradio.live
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 2644920617365642325
# [Parameters] CFG = 4
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_l.logit_scale'}
# left over keys: dict_keys(['conditioner.embedders.0.logit_scale', 'conditioner.embedders.0.text_projection'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.17 seconds
# Base model loaded: /content/Fooocus/models/checkpoints/SDXXXL.safetensors
# VAE loaded: None
# Request to load LoRAs [('RealisticPussy.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/SDXXXL.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/RealisticPussy.safetensors] for UNet [/content/Fooocus/models/checkpoints/SDXXXL.safetensors] with 722 keys at weight 0.1.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.90 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] high quality Photograph of a fit woman in her mid 20's, small bust, Canon EOS R3, wide hips, beach, energetic, bikini, thong, shirtlift, tits, full modern stylish cinematic composition, gentle open kinetic dynamic radiant light, detailed, cute, divine, elegant, intricate, highly vivid, rich deep colors, epic excellent crisp, sharp focus
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] high quality Photograph of a fit woman in her mid 20's, small bust, Canon EOS R3, wide hips, beach, energetic, bikini, thong, shirtlift, tits, full modern stylish, professional, gorgeous, breathtaking, intricate, highly detailed, beautiful, light, sharp focus, pretty background, cinematic, real, rich bright colors, ambient, elegant
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.08 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.57 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.41 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 65.04 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.14 seconds
# 100% 60/60 [00:58<00:00,  1.02it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-19/log.html
# Generating and saving time: 64.13 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.90 seconds
#  10% 6/60 [00:06<01:01,  1.14s/it]
# User stopped
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 71.88 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 137.00 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.90 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 7101149337133807431
# [Parameters] CFG = 4
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Request to load LoRAs [('Sexy underwear.safetensors', 0.89)] for model [/content/Fooocus/models/checkpoints/SDXXXL.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/Sexy underwear.safetensors] for UNet [/content/Fooocus/models/checkpoints/SDXXXL.safetensors] with 722 keys at weight 0.89.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 1.72 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] (masterpiece, photo of the highest quality), 1 girl, 21 years old, ((Russian blonde)), irresistible beauty, petite body, (beautiful and aesthetically pleasing:1, 2), transparent dress, small round breasts, beautiful pussy, clitoris, labia, vagina, necklace, creamy smooth skin, (top model), bright eyes, laying on her back spread legs to show pussy and asshole inviting some cock, dynamic angle, in the style of suicide girls, night, neon backlight in blue-green color, cozy room, epic, bright lighting, cinematic, highly detailed, very coherent, sharp focus, great composition, vivid colors, elegant, perfect background, professional, artistic, charismatic, cute, expressive, pretty, attractive
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] Woman (ethnicity:1.2), (age:35-45), (detailed clothing:1.2), (accessories:1.1), wearing a red sleeveless top (detailed fabric texture:1.2), and light-gray skirt, (facial features:1.3), (expression:1.2), smiling, (body type:1.1), (pose:1.2), standing in a casual pose, facing the viewer, (light skin tone), medium-length wavy light brown hair, (natural light), (bright smile), (small necklace:1.1), center of frame, slightly above eye level, casual indoor setting, decorated with gold balloons, and abstract backdrop of dark black and white stars on a wall. Soft lighting, warm colors, photorealistic style, digital art, high detail, 8k resolution, intricate detailed, beautiful, cinematic, rich aesthetic, very inspirational, lucid expressive, creative, positive, lively, elegant, perfect, focused, passionate, innocent, color, inspired, gorgeous, epic, stunning, illuminated
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.22 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.58 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.51 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 9.96 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.00 seconds
# 100% 60/60 [01:08<00:00,  1.15s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-19/log.html
# Generating and saving time: 72.93 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.70 seconds
# 100% 60/60 [01:07<00:00,  1.12s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-19/log.html
# Generating and saving time: 72.15 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 145.08 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 155.10 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.94 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 3820693512537255139
# [Parameters] CFG = 4
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_l.logit_scale'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model

# %%
# Out:
# --2025-02-19 12:11:20--  https://civitai.com/api/download/models/133037?type=Model&format=SafeTensor
# Resolving civitai.com (civitai.com)... 172.67.12.143, 104.22.19.237, 104.22.18.237, ...
# Connecting to civitai.com (civitai.com)|172.67.12.143|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/108598/model/topless20v1aFro095.3Zmi.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22topless%20v1a_fro0.95.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250219/us-east-1/s3/aws4_request&X-Amz-Date=20250219T121121Z&X-Amz-SignedHeaders=host&X-Amz-Signature=a0c5ec7d7857834d102dc9f8fe230cc9a0d21ef2472dcb3bb6251f6c85338aa8 [following]
# --2025-02-19 12:11:21--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/108598/model/topless20v1aFro095.3Zmi.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22topless%20v1a_fro0.95.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250219/us-east-1/s3/aws4_request&X-Amz-Date=20250219T121121Z&X-Amz-SignedHeaders=host&X-Amz-Signature=a0c5ec7d7857834d102dc9f8fe230cc9a0d21ef2472dcb3bb6251f6c85338aa8
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 172.66.1.46, 162.159.141.50, 2a06:98c1:58::12e, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|172.66.1.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92958468 (89M) [application/octet-stream]
# Saving to: ‘133037?type=Model&format=SafeTensor’
#
# 133037?type=Model&f 100%[===================>]  88.65M  68.6MB/s    in 1.3s
#
# 2025-02-19 12:11:22 (68.6 MB/s) - ‘133037?type=Model&format=SafeTensor’ saved [92958468/92958468]

# %%
# Out:
# '133037?type=Model&format=SafeTensor'	  hash_cache.txt
# '133037?type=Model&format=SafeTensor.1'   javascript
# '136277?type=Model&format=SafeTensor'	  language
#  args_manager.py			  launch.py
#  auth-example.json			  ldm_patched
#  build_launcher.py			  LICENSE
#  config_modification_tutorial.txt	  models
#  config.txt				  modules
#  css					  notification-example.mp3
#  development.md				  outputs
#  docker-compose.yml			  presets
#  Dockerfile				  __pycache__
#  docker.md				  readme.md
#  entrypoint.sh				  requirements_docker.txt
#  entry_with_update.py			  requirements_versions.txt
#  environment.yaml			  sdxl_styles
#  experiments_expansion.py		  shared.py
#  experiments_face.py			  sorted_styles.json
#  experiments_interrogate.py		  tests
#  experiments_mask_generation.py		  troubleshoot.md
#  extras					  update_log.md
#  fooocus_colab.ipynb			  webui.py
#  fooocus_version.py			  wildcards

# %%
# !wget "https://civitai.com/api/download/models/871108?type=Model&format=SafeTensor&token=2762a56d4bd82ffbf99ed0a0344438ea"
# Out:
# --2025-02-19 13:19:53--  https://civitai.com/api/download/models/871108?type=Model&format=SafeTensor&token=2762a56d4bd82ffbf99ed0a0344438ea
# Resolving civitai.com (civitai.com)... 104.22.19.237, 104.22.18.237, 172.67.12.143, ...
# Connecting to civitai.com (civitai.com)|104.22.19.237|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/1276645/pussyLilyV5XL.YueS.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22Pussy_Lily_v5_XL.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250219/us-east-1/s3/aws4_request&X-Amz-Date=20250219T131953Z&X-Amz-SignedHeaders=host&X-Amz-Signature=50a183ea04b7b2e24b4ecd20d2f1cb89d136d5d903eba111c1232390f91185c0 [following]
# --2025-02-19 13:19:54--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/1276645/pussyLilyV5XL.YueS.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22Pussy_Lily_v5_XL.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250219/us-east-1/s3/aws4_request&X-Amz-Date=20250219T131953Z&X-Amz-SignedHeaders=host&X-Amz-Signature=50a183ea04b7b2e24b4ecd20d2f1cb89d136d5d903eba111c1232390f91185c0
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 162.159.141.50, 172.66.1.46, 2a06:98c1:58::12e, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|162.159.141.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 681241492 (650M)
# Saving to: ‘871108?type=Model&format=SafeTensor&token=2762a56d4bd82ffbf99ed0a0344438ea’
#
# 871108?type=Model&f 100%[===================>] 649.68M  54.7MB/s    in 12s
#
# 2025-02-19 13:20:06 (55.8 MB/s) - ‘871108?type=Model&format=SafeTensor&token=2762a56d4bd82ffbf99ed0a0344438ea’ saved [681241492/681241492]

# %%
# !wget "https://civitai.com/api/download/models/133037?type=Model&format=SafeTensor"
# Out:
# --2025-02-19 12:18:51--  https://civitai.com/api/download/models/394030?type=Model&format=SafeTensor&token=5d95130d2fd0b9491febd0e48af42dfa
# Resolving civitai.com (civitai.com)... 104.22.19.237, 172.67.12.143, 104.22.18.237, ...
# Connecting to civitai.com (civitai.com)|104.22.19.237|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/2621028/sdxlHairyV15LITE.g88c.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22SDXL_hairy_v1.5_LITE.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250219/us-east-1/s3/aws4_request&X-Amz-Date=20250219T121851Z&X-Amz-SignedHeaders=host&X-Amz-Signature=9e0d1b065198b270f78c07f21b53a6a57eb53e1b561ca79007ad40f67563a4de [following]
# --2025-02-19 12:18:51--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/2621028/sdxlHairyV15LITE.g88c.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22SDXL_hairy_v1.5_LITE.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250219/us-east-1/s3/aws4_request&X-Amz-Date=20250219T121851Z&X-Amz-SignedHeaders=host&X-Amz-Signature=9e0d1b065198b270f78c07f21b53a6a57eb53e1b561ca79007ad40f67563a4de
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 172.66.1.46, 162.159.141.50, 2a06:98c1:58::12e, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|172.66.1.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 228460084 (218M)
# Saving to: ‘394030?type=Model&format=SafeTensor&token=5d95130d2fd0b9491febd0e48af42dfa’
#
# 394030?type=Model&f 100%[===================>] 217.88M  87.0MB/s    in 2.5s
#
# 2025-02-19 12:18:54 (87.0 MB/s) - ‘394030?type=Model&format=SafeTensor&token=5d95130d2fd0b9491febd0e48af42dfa’ saved [228460084/228460084]
